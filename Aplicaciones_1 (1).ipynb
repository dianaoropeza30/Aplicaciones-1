# %% [markdown]
# ![Captura de pantalla 2023-07-09 212440.png](data:image/png;base64,...)

# %%
import numpy as np
def f(x):
  return (5.621261 + 0.178953 * x) * np.e ** (0.178953 * t) - 4.36859
def g(x):
  return (1.184895 + 0.032024 * x) * np.e ** (0.178953 * x)
p_n = float (input ("Ingresa la primera aproximación: "))
error = float (input ("Ingresa el error de la aproximación: "))
e, c = 1, 0
print(f"n \t\t P_n \t\t\t Error")
while e > error:
  print(f"{c}\t {p_n}\t{e}")
  c += 1
  t = p_n
  if g(p_n) != 0:
    p_n -= f(p_n) / g(p_n)
  else:
    print("Divisón por cero")
    break
  e = abs(t - p_n)
if g(p_n) != 0:
  print(f"{c} \t {p_n} \t{abs(t - p_n)}")
  print(f"\n La raíz con un error de {error} es aproximadamente {p_n}")
# Out:
# Ingresa la primera aproximación: -1
# Ingresa el error de la aproximación: 0.000001
# n 		 P_n 			 Error
# 0	 -1.0	1
# 1	 -1.1887715996890686	0.18877159968906865
# 2	 -1.1925532801554792	0.0037816804664105863
# 3	 -1.192554762496123	1.4823406437880493e-06
# 4 	 -1.192554762497243 	1.119992987241858e-12
#
#  La raíz con un error de 1e-06 es aproximadamente -1.192554762497243

# %% [markdown]
# ![Captura de pantalla 2023-07-09 213423.png](data:image/png;base64,...)

# %% [markdown]
# # **Solución a)**
#
#
# *Tenemos la siguiente ecuacion diferencial:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 214254.png](data:image/png;base64,...)

# %% [markdown]
# Usamos *t = 0* como el tiempo de detención de los sospechosos

# %% [markdown]
# *Resolviendo por variables separables obtenemos lo siguiente:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 214807.png](data:image/png;base64,...)

# %% [markdown]
# *Usando los datos del problema y sustituyendo en la ecuación anterior:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 214954.png](data:image/png;base64,...)

# %% [markdown]
# Despejando la ecuación (1) y sustituyendo el valor de *k*
#  y *x = 37* se obtiene

# %% [markdown]
# ![Captura de pantalla 2023-07-09 215312.png](data:image/png;base64,...)

# %% [markdown]
# **Por lo tanto, el disparo al jabalí fue hecho 2 horas, 6 minutos y 23 segundos antes de que los sospechosos fueran detenidos**

# %% [markdown]
# # **Solución b)**

# %% [markdown]
# *En este caso, ya que la temperatura del ambiente cambia respecto al tiempo tenemos la ecuación diferencial:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 230339.png](data:image/png;base64,...)

# %% [markdown]
# Tomando t = 0 como el momento del disparo, y t* como el instante en el que los guardabosques descubrieron el cadáver, *obtenemos*:

# %% [markdown]
# ![Captura de pantalla 2023-07-09 230841.png](data:image/png;base64,...)

# %% [markdown]
# *Sustituyendo en la ecuacion (1) y resolviendo llegamos a:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 231005.png](data:image/png;base64,...)

# %% [markdown]
# Teniendo en cuenta que x = 30 para t* , y x = 25 para t = t*+1, de la última expresión obtenemos las siguientes igualdades:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# *obtenemos:*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 232217.png](data:image/png;base64,...)

# %% [markdown]
# La ecuación (2), después de tomar x =37, toma la forma:

# %% [markdown]
# ![Captura de pantalla 2023-07-09 232337.png](data:image/png;base64,...)

# %% [markdown]
# *Para resolver esto hacemos uso del método de Newton-Raphson, reescribimos a (2):*

# %% [markdown]
# ![Captura de pantalla 2023-07-09 232545.png](data:image/png;base64,...)

# %% [markdown]
# Luego definimos *f (k)* y derivamos

# %% [markdown]
# ![Captura de pantalla 2023-07-09 232754.png](data:image/png;base64,...)

# %% [markdown]
# Notamos que* f'(k) = 0* si *k = 0.0914595* Además *f(0.1) = 0.2317* y *f(1) = -38.95*, lo que nos dice que hay una raíz en [0.1,1]

# %% [markdown]
# Procedemos a usar el método de Newton con x_0 = 0.5

# %% [markdown]
# Usando el programa realizado en el curso, tenemos que *k = 0.178953*, sustituimos el valor de k
#  en la ecuacion (4)

# %% [markdown]
# ![Captura de pantalla 2023-07-09 233538.png](data:image/png;base64,...)

# %% [markdown]
# Para encontrar el valor de *t* , procedemos de forma análoga:

# %% [markdown]
# ![Captura de pantalla 2023-07-09 234039.png](data:image/png;base64,...)

# %% [markdown]
# Entonces *t = 1.192555*

# %% [markdown]
# **Finalmente, podemos decir que el jabalí murió 1 hora, 11 minutos y 33 segundos antes de que lo encontraran.**
